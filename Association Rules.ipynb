# %% [markdown]
# # Installons la librairie MLxtend.

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importons les librairies et outils necessaires et chargeons nos données.

# %%
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
        ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
        ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
        ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
      ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)   
xx=pd.DataFrame(te_ary, columns=te.columns_)
xx.head()
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %% [markdown]
# # Let's use Apriori Concept

# %%
# Support

from mlxtend.frequent_patterns import apriori
frequent_itemsets=apriori(xx, min_support=0.6, use_colnames=True) 
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Skirt, Pants)

# %%
# Confidence

from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 3     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        1.00  1.2500      0.12         inf
# 3        0.75  1.2500      0.12         1.6

# %%
# Lift

association_rules(frequent_itemsets,metric="lift",min_threshold=1)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 1     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence  lift  leverage  conviction
# 0        1.00  1.25      0.12         inf
# 1        0.75  1.25      0.12         1.6

# %%
import pandas as pd
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
data.shape
# Out:
# (7501, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %%
column = []  
for i in range(0, 7501):  
    column.append([str(data.values[i,j]) for j in range(0, 20)])

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

te = TransactionEncoder()
te_ary = te.fit(column).transform(column)
data = pd.DataFrame(te_ary, columns=te.columns_)
data
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
apriori(data, min_support=0.0045)
# Out:
#        support               itemsets
# 0     0.020397                    (1)
# 1     0.008932                    (2)
# 2     0.004666                    (3)
# 3     0.033329                    (4)
# 4     0.004533                    (5)
# ...        ...                    ...
# 1679  0.006266     (72, 101, 117, 77)
# 1680  0.005066      (101, 82, 83, 77)
# 1681  0.004533  (101, 37, 72, 77, 25)
# 1682  0.004933  (101, 71, 72, 77, 25)
# 1683  0.004533  (101, 71, 72, 77, 49)
#
# [1684 rows x 2 columns]

# %%
frequent_itemsets = apriori(data, min_support=0.0045, use_colnames=True)
frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.020397                                          (almonds)
# 1     0.008932                                (antioxydant juice)
# 2     0.004666                                        (asparagus)
# 3     0.033329                                          (avocado)
# 4     0.004533                                      (babies food)
# ...        ...                                                ...
# 1679  0.006266  (whole wheat rice, nan, mineral water, spaghetti)
# 1680  0.005066              (olive oil, nan, pancakes, spaghetti)
# 1681  0.004533   (spaghetti, chocolate, nan, mineral water, eggs)
# 1682  0.004933   (spaghetti, milk, chocolate, nan, mineral water)
# 1683  0.004533  (spaghetti, frozen vegetables, milk, nan, mine...
#
# [1684 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.007)
# Out:
#                antecedents                                        consequents  \
# 0                (almonds)                                          (burgers)
# 1                (burgers)                                          (almonds)
# 2                (almonds)                                        (chocolate)
# 3              (chocolate)                                          (almonds)
# 4                (almonds)                                             (eggs)
# ...                    ...                                                ...
# 8356  (nan, mineral water)               (frozen vegetables, milk, spaghetti)
# 8357           (spaghetti)      (frozen vegetables, milk, nan, mineral water)
# 8358   (frozen vegetables)              (milk, nan, mineral water, spaghetti)
# 8359                (milk)  (frozen vegetables, nan, mineral water, spaghe...
# 8360       (mineral water)          (frozen vegetables, milk, nan, spaghetti)
#
# ...

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="lift", min_threshold=1.25)
# Out:
#                antecedents                                        consequents  \
# 0                (almonds)                                          (burgers)
# 1                (burgers)                                          (almonds)
# 2                (almonds)                                        (chocolate)
# 3              (chocolate)                                          (almonds)
# 4                (almonds)                                             (eggs)
# ...                    ...                                                ...
# 5865  (nan, mineral water)               (frozen vegetables, milk, spaghetti)
# 5866           (spaghetti)      (frozen vegetables, milk, nan, mineral water)
# 5867   (frozen vegetables)              (milk, nan, mineral water, spaghetti)
# 5868                (milk)  (frozen vegetables, nan, mineral water, spaghe...
# 5869       (mineral water)          (frozen vegetables, milk, nan, spaghetti)
#
# ...
